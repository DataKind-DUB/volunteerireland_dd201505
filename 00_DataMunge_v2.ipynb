# %% [markdown]
# # 00_DataMunge_v2
#
# Volunteer Ireland

# %%
## Interactive magics - comment out if running from another script
# %matplotlib inline
# %qtconsole --colors=linux --ConsoleWidget.font_size=12 --ConsoleWidget.font_family='Consolas'

# %%
import sqlite3
import string
# import re
import numpy as np
import pandas as pd
# import patsy as pt

pd.set_option('display.mpl_style', 'default')
pd.set_option('display.notebook_repr_html', True)
np.random.seed(0)

# %%
cnx = sqlite3.connect('data/volunteerireland_datadive2015.db')

# %% [markdown]
# # Read Data

# %% [markdown]
# ## Opps all time

# %%
dfoppsaltm = pd.read_excel('data/df_oppsaltm.xlsx') #dtype={'GEOGID':str,'GEOGTYPE':str,'GEOGDESC':str})
dfoppsaltm.rename(columns=lambda x: 'altm_{}'.format('_'.join([y.strip(string.punctuation) for y in x.lower().split()])), inplace=True)
dfoppsaltm['altm_id'] = np.arange(dfoppsaltm.shape[0])
print(dfoppsaltm.shape)
dfoppsaltm.head()
# Out:
# (35494, 29)
#   altm_created_date altm_volunteer_opportunity_id altm_organisation_id  \
# 0        2015-05-14               a00D000000a2hWM      001D000001hzVeF
# 1        2015-05-13               a00D000000a2fnU      001D000001hzHbI
# 2        2015-05-12               a00D000000a2ejO      001D000001hz3rh
# 3        2015-05-12               a00D000000a2edf      001D000001hz1WN
# 4        2015-05-12               a00D000000a2ecw      001D000001hz175
#
#                   altm_organisation_name  \
# 0                       Involve Salthill
# 1                           Bloom Fringe
# 2                    Make-A-Wish Ireland
# 3     Knockatallon Community Development
# 4  Multiple Sclerosis Society of Ireland
#
#   altm_volunteer_opportunity_volunteer_opportunity  \
# 0                               Cycle group leader
# 1                   Festival Steward - City Centre
# 2                       County Volunteer Wish Team
# 3           Road Marshalling for Fundraising Event
# 4  a companion to a person with multiple sclerosis
#
#   altm_activity_that_reflects_opportunity   altm_volunteer_bureau altm_county  \
# 0     Sports/out door activities/Coaching                  Galway      Galway
# 1                   Events and stewarding             Dublin City      Dublin
# 2                 Support and Key working  Dun Laoghaire/Rathdown      Dublin
# 3                   Events and stewarding                Monaghan    Monaghan
# 4                   Befriending/Mentoring             Dublin City      Dublin
#
#                                         altm_morning  \
# 0                                                NaN
# 1                                           Saturday
# 2  Monday; Tuesday; Wednesday; Thursday; Friday; ...
# 3                                                NaN
# 4                                                NaN
#
#                                       altm_afternoon   ...     \
# 0                                                NaN   ...
# 1                                           Saturday   ...
# 2  Monday; Tuesday; Wednesday; Thursday; Friday; ...   ...
# 3                                                NaN   ...
# 4  Monday; Tuesday; Wednesday; Thursday; Friday; ...   ...
#
#   altm_publish_direct_contact altm_active altm_number_of_volunteers_required  \
# 0                           0           0                                  2
# 1                           1           1                                 20
# 2                           0           0                                  5
# 3                           0           0                                 10
# 4                           0           0                                  1
#
#   altm_automatic_de-activation_date altm_publish_date  \
# 0                        2015-06-30               NaT
# 1                        2015-05-31        2015-05-14
# 2                        2016-07-16               NaT
# 3                        2015-08-12               NaT
# 4                        2015-08-12               NaT
#
#                                 altm_skills_required  \
# 0                            Fitness/ Health/ Beauty
# 1   Event management/ Fundraising; Personable Skills
# 2  Hospitality/ Befriending; Personable Skills; Y...
# 3                                                NaN
# 4                                  Personable Skills
#
#                      altm_skills/qualities_necessary  \
# 0  Good communication skills; motivational skills...
# 1  No specific skills but a willingness to engage...
# 2  Skills required are friendly manner, listening...
# 3                                                NaN
# 4  someone who likes dogs! and could befriend the...
#
#   altm_suitable_for_corporates/groups  \
# 0                                 Yes
# 1                                 Yes
# 2                                 Yes
# 3                                 Yes
# 4                                  No
#
#                           altm_benefits_to_volunteer  altm_id
# 0  The volunteer will gain experience in both co-...        0
# 1                                                NaN        1
# 2                                                NaN        2
# 3                                                NaN        3
# 4  contact from a person living with multiple scl...        4
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Orgs

# %%
dforgs = pd.read_excel('data/df_orgs.xlsx')
dforgs.rename(columns=lambda x: 'orgs_{}'.format('_'.join([y.strip(string.punctuation) for y in x.lower().split()])), inplace=True)
dforgs['orgs_id'] = np.arange(dforgs.shape[0])
print(dforgs.shape)
dforgs.head()
# Out:
# (7764, 16)
#   orgs_created_date orgs_organisation_id  \
# 0        2012-12-18      001D000000zg6AQ
# 1        2012-08-14      001D000000tvhyQ
# 2        2007-01-23      00120000004o3iu
# 3        2012-10-02      001D000000w8uw9
# 4        2008-05-14      0012000000A4dWS
#
#                    orgs_organisation_name orgs_county orgs_local_area__dublin  \
# 0                           Cork Job Club        Cork                     NaN
# 1  Knocknaheeny/Hollyhill Justice Project        Cork                     NaN
# 2            Lough Parish Meals On Wheels        Cork                     NaN
# 3             Focus Ireland - Cork branch        Cork                     NaN
# 4                 Cork Sports Partnership        Cork                     NaN
#
#                            orgs_aims_of_organisation orgs_volunteer_bureau  \
# 0  Cork Job Club aims to expand awareness and hel...                  Cork
# 1  The project's main focus is as a Garda Youth D...                  Cork
# 2  To provide meals on wheels mainly to the elder...                  Cork
# 3  Focus Ireland works to prevent people becoming...                  Cork
# 4  The mission of Cork Sports Partnership is to i...                  Cork
#
#   orgs_organisation_status   orgs_cause_of_organisation  \
# 0                   Active                 Unemployment
# 1                   Active             Social Inclusion
# 2                   Active  Older People/Active Retired
# 3                   Active        Homelessness/ Housing
# 4                   Active    Sports/Outdoor activities
#
#   orgs_how_did_you_hear_about_our_service  \
# 0                           Word of Mouth
# 1                           Word of Mouth
# 2                           Word of Mouth
# 3                           Word of Mouth
# 4                           Word of Mouth
#
#   orgs_which_best_describes_your_organisation  \
# 0                          Registered Charity
# 1                          Registered Charity
# 2                          Registered Charity
# 3                          Registered Charity
# 4           Non Profit without Charity Number
#
#   orgs_do_you_have_a_volunteer_policy orgs_how_many_volunteers_do_you_involve  \
# 0                                  No                      less than 5 people
# 1                                 Yes                      less than 5 people
# 2                                  No                             5-10 people
# 3                                 Yes  We currently do not involve volunteers
# 4                                 Yes  We currently do not involve volunteers
#
#   orgs_how_many_employees_are_in_your_org  \
# 0                      less than 5 people
# 1                      less than 5 people
# 2                      less than 5 people
# 3                             5-10 people
# 4                             5-10 people
#
#                    orgs_how_do_you_manage_volunteers  orgs_id
# 0  We have a paid member of staff who is a part-t...        0
# 1  We have a paid member of staff who is a full-t...        1
# 2  We have a volunteer who is responsible for Vol...        2
# 3  We have a paid member of staff who is a full-t...        3
# 4  Volunteer Management is shared between staff a...        4

# %% [markdown]
# ## Opps applied for

# %%
dfoppsapfr = pd.read_excel('data/df_oppsapfr.xlsx')
dfoppsapfr.rename(columns=lambda x: 'apfr_{}'.format('_'.join([y.strip(string.punctuation) for y in x.lower().split()])), inplace=True)
dfoppsapfr['apfr_id'] = np.arange(dfoppsapfr.shape[0])
print(dfoppsapfr.shape)
dfoppsapfr.head()
# Out:
# (110612, 10)
#   apfr_volunteer_opportunity_applied_for_volunteer_opportunity_applied_for__name  \
# 0                                        2015-188435
# 1                                        2015-188434
# 2                                        2015-188433
# 3                                        2015-188432
# 4                                        2015-188431
#
#    apfr_volunteers_required  \
# 0                         1
# 1                         1
# 2                         4
# 3                         5
# 4                         1
#
#   apfr_volunteer_opportunity_applied_for_created_date  \
# 0                                         2015-05-05
# 1                                         2015-05-05
# 2                                         2015-05-05
# 3                                         2015-05-05
# 4                                         2015-05-05
#
#   apfr_volunteer_volunteer_id apfr_volunteer_opportunity_applied_for_id  \
# 0             00QD000000r6Ni2                           a04D000000aYWaQ
# 1             00QD000000prM1r                           a04D000000aYWaL
# 2             00QD000000QofvS                           a04D000000aYWaG
# 3             00QD000000r5HY5                           a04D000000aYWaB
# 4             00QD000000r6NO0                           a04D000000aYWa6
#
#      apfr_vop_name apfr_volunteer_opportunity_applied_for  \
# 0  a00D000000LNaRk                   Family Law Mediators
# 1  a00D000000a2Gym       Community Engagement Team Member
# 2  a00D000000a2KoB          Darkness Into Light Walk 2015
# 3  a00D000000WZTvk             Information Liason Officer
# 4  a00D000000LLe1w           Douglas Tidy Towns Volunteer
#
#               apfr_organisation_name      apfr_current_status_of_application  \
# 0    The Guardian Children's Project         Registered interest in this Opp
# 1                           BlueFire         Registered interest in this Opp
# 2  Pieta House - Darkness into Light       Passed on details to organisation
# 3                     EnGage Kildare         Registered interest in this Opp
# 4                 Douglas Tidy Towns  Details of contact passed to volunteer
#
#    apfr_id
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4

# %%
# print(dfoppsapfr.loc[pd.isnull(dfoppsapfr['volunteer:_volunteer_id'])].shape)
# dfoppsapfr.groupby(['volunteer:_volunteer_id']).size().order()[-20:]

# %%
# dfoppsapfr.groupby(['volunteer:_volunteer_id']).size().order().plot(figsize=(10,4))

# %% [markdown]
# ## Opps Placed

# %%
dfplc = pd.read_excel('data/df_plc.xlsx')
dfplc.rename(columns=lambda x: 'plc_{}'.format('_'.join([y.strip(string.punctuation) for y in x.lower().split()])), inplace=True)
dfplc['plc_id'] = np.arange(dfplc.shape[0])
print(dfplc.shape)
dfplc.head()
# Out:
# (39821, 12)
#   plc_place_volunteer_connector plc_volunteer_id plc_place_volunteer_id  \
# 0                       v-10825  00Q2000000E7TXM        a012000000QQACg
# 1                       v-33133  00QD000000ekhy5        a01D000000lWTIj
# 2                       v-40009  00QD000000XHKN2        a01D000000rEETh
# 3                       v-11012  00Q2000000E83Nm        a012000000QQTTv
# 4                       v-11994  00Q2000000BAHaT        a012000000Sapby
#
#   plc_place_volunteer_created_date plc_volunteer_opportunity_created_date  \
# 0                       2009-11-30                             2007-10-30
# 1                       2013-10-14                             2011-09-15
# 2                       2014-11-18                             2013-08-06
# 3                       2009-12-10                             2009-05-08
# 4                       2010-03-09                             2009-01-14
#
#   plc_volunteer_opportunity_record_id plc_volunteer_registered_centre  \
# 0                     a0020000004lHjP                         Kildare
# 1                     a00D000000IOigU                          Offaly
# 2                     a00D000000Q5juz          Dun Laoghaire/Rathdown
# 3                     a002000000AkGnM          Dun Laoghaire/Rathdown
# 4                     a0020000009dQuO                           Sligo
#
#                                     plc_organisation  plc_volunteer_hours  \
# 0                                     The Bridge CDP                  104
# 1             Birr Mentality Handicapped Association                   12
# 2  Society of St. Vincent de Paul - SVP Dublin Re...                  104
# 3                                 Making Connections                   20
# 4                                 Irish Therapy Dogs                   52
#
#   plc_volunteer_opportunity_volunteer_centre  \
# 0                                    Kildare
# 1                                        NaN
# 2                                Dublin City
# 3                                        NaN
# 4                                      Sligo
#
#      plc_volunteer_opportunity_volunteer_opportunity  plc_id
# 0                           Homework Club Mentor CDP       0
# 1                                     Support Worker       1
# 2  Volunteer for Society of Saint Vincent de Paul...       2
# 3                                         Web Design       3
# 4                                        Pet Visitor       4

# %% [markdown]
# ## Volunteers

# %%
dfvol = pd.read_excel('data/df_vol.xlsx')
dfvol.rename(columns=lambda x: 'vol_{}'.format('_'.join([y.strip(string.punctuation) for y in x.lower().split()])), inplace=True)
dfvol['vol_id'] = np.arange(dfvol.shape[0])
print(dfvol.shape)
dfvol.head()
# Out:
# (103035, 22)
#   vol_volunteer_id vol_create_date vol_how_long_do_you_wish_to_volunteer_for  \
# 0  00Q2000000E7wXL      2009-11-09                                       NaN
# 1  00Q2000000Hl336      2010-05-19                                       NaN
# 2  00QD000000NXhm2      2011-05-17                                       NaN
# 3  00QD000000QoUOG      2011-11-17                                       NaN
# 4  00QD000000Uye1D      2012-07-04                                       NaN
#
#   vol_age_group vol_why_do_you_want_to_volunteer_now vol_volunteer_status  \
# 0         36-49              Recently made redundant           Registered
# 1         16-25                            Free time  Registered Interest
# 2         50-59                      Work Experience           Registered
# 3         26-35                  Because I was asked           Registered
# 4         26-35                            Free time           Registered
#
#   vol_method_of_contact_with_volunteer vol_face_to_face vol_gender  \
# 0                                  NaN              NaN       Male
# 1            Contact by phone/internet      Appointment       Male
# 2            Contact by phone/internet              NaN     Female
# 3                                  NaN              NaN       Male
# 4            Contact by phone/internet              NaN     Female
#
#   vol_nationality  ...   vol_volunteered_before vol_volunteer_bureau  \
# 0           Irish  ...                       No               Galway
# 1      Zimbabwean  ...                       No                 Cork
# 2        Nigerian  ...                       No  South Dublin County
# 3           Irish  ...                      Yes               Galway
# 4           Irish  ...                       No  South Dublin County
#
#   vol_local_area__dublin          vol_volunteer_recruitment_method  \
# 0                    NaN                           Internet Search
# 1                    NaN                           Internet Search
# 2                    NaN                           Internet Search
# 3                    NaN  Word of Mouth/Referred by another agency
# 4                    NaN  Word of Mouth/Referred by another agency
#
#   vol_activity_you_are_interested_in vol_cause_you_are_interested_in  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2         Administrative/Office work                          Carers
# 3                                NaN                             NaN
# 4                                NaN                             NaN
#
#                                 vol_skills_qualities vol_skills_profile  \
# 0  Worked in computer support for over 11 years, ...                NaN
# 1  Ecdl -Coumputer course  retail experience kitc...                NaN
# 2  Practical Care Skills\nManual Handling Skills\...                NaN
# 3                                           Various.                NaN
# 4  I have worked in administration in the offices...                NaN
#
#   vol_county vol_id
# 0        NaN      0
# 1        NaN      1
# 2     Dublin      2
# 3        NaN      3
# 4        NaN      4
#
# [5 rows x 22 columns]

# %% [markdown]
# ---
#
# ---

# %% [markdown]
# # Join some stuuf

# %%
df1 = pd.merge(dfoppsaltm[['altm_id','altm_organisation_id','altm_volunteer_opportunity_id']]
               ,dforgs[['orgs_id','orgs_organisation_id']]
               ,how='left', left_on='altm_organisation_id', right_on='orgs_organisation_id')
print(df1.shape)
df1.head().T
# Out:
# (35494, 5)
#                                              0                1  \
# altm_id                                      0                1
# altm_organisation_id           001D000001hzVeF  001D000001hzHbI
# altm_volunteer_opportunity_id  a00D000000a2hWM  a00D000000a2fnU
# orgs_id                                    NaN              NaN
# orgs_organisation_id                       NaN              NaN
#
#                                              2                3  \
# altm_id                                      2                3
# altm_organisation_id           001D000001hz3rh  001D000001hz1WN
# altm_volunteer_opportunity_id  a00D000000a2ejO  a00D000000a2edf
# orgs_id                                    NaN              NaN
# orgs_organisation_id                       NaN              NaN
#
#                                              4
# altm_id                                      4
# altm_organisation_id           001D000001hz175
# altm_volunteer_opportunity_id  a00D000000a2ecw
# orgs_id                                    NaN
# orgs_organisation_id                       NaN

# %%
df2 = pd.merge(df1
               ,dfoppsapfr[['apfr_id','apfr_vop_name','apfr_volunteer_volunteer_id']]
               , how='left', left_on='altm_volunteer_opportunity_id', right_on='apfr_vop_name')
print(df2.shape)
df2.head().T
# Out:
# (128023, 8)
#                                              0                1  \
# altm_id                                      0                1
# altm_organisation_id           001D000001hzVeF  001D000001hzHbI
# altm_volunteer_opportunity_id  a00D000000a2hWM  a00D000000a2fnU
# orgs_id                                    NaN              NaN
# orgs_organisation_id                       NaN              NaN
# apfr_id                                    NaN              NaN
# apfr_vop_name                              NaN              NaN
# apfr_volunteer_volunteer_id                NaN              NaN
#
#                                              2                3  \
# altm_id                                      2                3
# altm_organisation_id           001D000001hz3rh  001D000001hz1WN
# altm_volunteer_opportunity_id  a00D000000a2ejO  a00D000000a2edf
# orgs_id                                    NaN              NaN
# orgs_organisation_id                       NaN              NaN
# apfr_id                                    NaN              NaN
# apfr_vop_name                              NaN              NaN
# apfr_volunteer_volunteer_id                NaN              NaN
#
#                                              4
# altm_id                                      4
# altm_organisation_id           001D000001hz175
# altm_volunteer_opportunity_id  a00D000000a2ecw
# orgs_id                                    NaN
# orgs_organisation_id                       NaN
# apfr_id                                    NaN
# apfr_vop_name                              NaN
# apfr_volunteer_volunteer_id                NaN

# %%
dfvol_apfr = dfvol.copy()
dfvol_apfr.rename(columns={'vol_id':'vol_id_apfr','vol_volunteer_id':'vol_volunteer_id_apfr'}, inplace=True)

df3 = pd.merge(df2
               ,dfvol_apfr[['vol_id_apfr','vol_volunteer_id_apfr']]
               ,how='left', left_on='apfr_volunteer_volunteer_id', right_on='vol_volunteer_id_apfr')
print(df3.shape)
df3.head().T
# Out:
# (128023, 10)
#                                              0                1  \
# altm_id                                      0                1
# altm_organisation_id           001D000001hzVeF  001D000001hzHbI
# altm_volunteer_opportunity_id  a00D000000a2hWM  a00D000000a2fnU
# orgs_id                                    NaN              NaN
# orgs_organisation_id                       NaN              NaN
# apfr_id                                    NaN              NaN
# apfr_vop_name                              NaN              NaN
# apfr_volunteer_volunteer_id                NaN              NaN
# vol_id_apfr                                NaN              NaN
# vol_volunteer_id_apfr                      NaN              NaN
#
#                                              2                3  \
# altm_id                                      2                3
# altm_organisation_id           001D000001hz3rh  001D000001hz1WN
# altm_volunteer_opportunity_id  a00D000000a2ejO  a00D000000a2edf
# orgs_id                                    NaN              NaN
# orgs_organisation_id                       NaN              NaN
# apfr_id                                    NaN              NaN
# apfr_vop_name                              NaN              NaN
# apfr_volunteer_volunteer_id                NaN              NaN
# vol_id_apfr                                NaN              NaN
# vol_volunteer_id_apfr                      NaN              NaN
#
#                                              4
# altm_id                                      4
# altm_organisation_id           001D000001hz175
# altm_volunteer_opportunity_id  a00D000000a2ecw
# orgs_id                                    NaN
# orgs_organisation_id                       NaN
# apfr_id                                    NaN
# apfr_vop_name                              NaN
# apfr_volunteer_volunteer_id                NaN
# vol_id_apfr                                NaN
# vol_volunteer_id_apfr                      NaN

# %%
df4 = pd.merge(df3
               , dfplc[['plc_id','plc_volunteer_opportunity_record_id','plc_volunteer_id']]
               , how='left', left_on='apfr_vop_name', right_on='plc_volunteer_opportunity_record_id')
print(df4.shape)
df4.head().T
# Out:
# (780548, 13)
#                                                    0                1  \
# altm_id                                            0                1
# altm_organisation_id                 001D000001hzVeF  001D000001hzHbI
# altm_volunteer_opportunity_id        a00D000000a2hWM  a00D000000a2fnU
# orgs_id                                          NaN              NaN
# orgs_organisation_id                             NaN              NaN
# apfr_id                                          NaN              NaN
# apfr_vop_name                                    NaN              NaN
# apfr_volunteer_volunteer_id                      NaN              NaN
# vol_id_apfr                                      NaN              NaN
# vol_volunteer_id_apfr                            NaN              NaN
# plc_id                                           NaN              NaN
# plc_volunteer_opportunity_record_id              NaN              NaN
# plc_volunteer_id                                 NaN              NaN
#
#                                                    2                3  \
# altm_id                                            2                3
# altm_organisation_id                 001D000001hz3rh  001D000001hz1WN
# altm_volunteer_opportunity_id        a00D000000a2ejO  a00D000000a2edf
# orgs_id                                          NaN              NaN
# orgs_organisation_id                             NaN              NaN
# apfr_id                                          NaN              NaN
# apfr_vop_name                                    NaN              NaN
# apfr_volunteer_volunteer_id                      NaN              NaN
# vol_id_apfr                                      NaN              NaN
# vol_volunteer_id_apfr                            NaN              NaN
# plc_id                                           NaN              NaN
# plc_volunteer_opportunity_record_id              NaN              NaN
# plc_volunteer_id                                 NaN              NaN
#
#                                                    4
# altm_id                                            4
# altm_organisation_id                 001D000001hz175
# altm_volunteer_opportunity_id        a00D000000a2ecw
# orgs_id                                          NaN
# orgs_organisation_id                             NaN
# apfr_id                                          NaN
# apfr_vop_name                                    NaN
# apfr_volunteer_volunteer_id                      NaN
# vol_id_apfr                                      NaN
# vol_volunteer_id_apfr                            NaN
# plc_id                                           NaN
# plc_volunteer_opportunity_record_id              NaN
# plc_volunteer_id                                 NaN

# %%
dfvol_plc = dfvol.copy()
dfvol_plc.rename(columns={'vol_id':'vol_id_plc','vol_volunteer_id':'vol_volunteer_id_plc'}, inplace=True)

df5 = pd.merge(df4
               ,dfvol_plc[['vol_id_plc','vol_volunteer_id_plc']]
               ,how='left', left_on='plc_volunteer_id', right_on='vol_volunteer_id_plc')
print(df5.shape)
df5.head().T
# Out:
# (780548, 15)
#                                                    0                1  \
# altm_id                                            0                1
# altm_organisation_id                 001D000001hzVeF  001D000001hzHbI
# altm_volunteer_opportunity_id        a00D000000a2hWM  a00D000000a2fnU
# orgs_id                                          NaN              NaN
# orgs_organisation_id                             NaN              NaN
# apfr_id                                          NaN              NaN
# apfr_vop_name                                    NaN              NaN
# apfr_volunteer_volunteer_id                      NaN              NaN
# vol_id_apfr                                      NaN              NaN
# vol_volunteer_id_apfr                            NaN              NaN
# plc_id                                           NaN              NaN
# plc_volunteer_opportunity_record_id              NaN              NaN
# plc_volunteer_id                                 NaN              NaN
# vol_id_plc                                       NaN              NaN
# vol_volunteer_id_plc                             NaN              NaN
#
#                                                    2                3  \
# altm_id                                            2                3
# altm_organisation_id                 001D000001hz3rh  001D000001hz1WN
# altm_volunteer_opportunity_id        a00D000000a2ejO  a00D000000a2edf
# orgs_id                                          NaN              NaN
# orgs_organisation_id                             NaN              NaN
# apfr_id                                          NaN              NaN
# apfr_vop_name                                    NaN              NaN
# apfr_volunteer_volunteer_id                      NaN              NaN
# vol_id_apfr                                      NaN              NaN
# vol_volunteer_id_apfr                            NaN              NaN
# plc_id                                           NaN              NaN
# plc_volunteer_opportunity_record_id              NaN              NaN
# plc_volunteer_id                                 NaN              NaN
# vol_id_plc                                       NaN              NaN
# vol_volunteer_id_plc                             NaN              NaN
#
#                                                    4
# altm_id                                            4
# altm_organisation_id                 001D000001hz175
# altm_volunteer_opportunity_id        a00D000000a2ecw
# orgs_id                                          NaN
# orgs_organisation_id                             NaN
# apfr_id                                          NaN
# apfr_vop_name                                    NaN
# apfr_volunteer_volunteer_id                      NaN
# vol_id_apfr                                      NaN
# vol_volunteer_id_apfr                            NaN
# plc_id                                           NaN
# plc_volunteer_opportunity_record_id              NaN
# plc_volunteer_id                                 NaN
# vol_id_plc                                       NaN
# vol_volunteer_id_plc                             NaN

# %% [markdown]
# ----

# %% [markdown]
# # Write to DB

# %% [markdown]
# ## Original Tables

# %%
dfoppsaltm.to_sql('dfoppsaltm', cnx, if_exists='replace')
dforgs.to_sql('dforgs', cnx, if_exists='replace')
dfoppsapfr.to_sql('dfoppsapfr', cnx, if_exists='replace')
dfplc.to_sql('dfplc', cnx, if_exists='replace')
dfvol.to_sql('dfvol', cnx, if_exists='replace')

# %% [markdown]
# ## Merged Table

# %%
df5.to_sql('vi_merged', cnx, if_exists='replace')

# %% [markdown]
# ---
