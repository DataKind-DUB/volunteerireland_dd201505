# %% [markdown]
# ####DataKind Dublin
#
# ## Volunteer Ireland DataDive Project 2015
# # Import Raw Data
#
# Quick & dirty import of raw csv files and write to sqlite3 db
#
# + [Setup](#Setup)
#     + [Local Functions](#Local-Functions)
#     + [Load Data](#Load Data)

# %% [markdown]
# # Setup

# %%
## Interactive magics - comment out if running from another script
# %matplotlib inline
# %qtconsole --colors=linux --ConsoleWidget.font_size=12 --ConsoleWidget.font_family='Consolas'

# %%
from __future__ import division, print_function
from collections import OrderedDict
import unicodedata
import sys
import re
import sqlite3

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Set some defaults
pd.set_option('display.mpl_style', 'default')
pd.set_option('display.notebook_repr_html', True)
np.random.seed(0)

# %% [markdown]
# ## Local Functions

# %%
remove_punct_map = dict.fromkeys(i for i in range(sys.maxunicode)
                      if unicodedata.category(chr(i)).startswith('P'))

def snakeycase(s,punctmap=remove_punct_map):
    """ return a string that has been stripped of punctuation, trimmed, lowercased 
        and spaces replaced by underscores .
        e.g. " I'm a Fan, of snakey-strings :) " -> "im_a_fan_of_snakeystrings"
    """
    newstring = s.translate(punctmap)
    return '_'.join(newstring.lower().split())

# %% [markdown]
# ## Load Data

# %% [markdown]
# #### Volunteer Info

# %%
raw_volunteers = pd.read_csv('datadrop_20150325/cleaned_csv/volunteers.csv')
raw_volunteers.rename(columns=lambda x: snakeycase(x), inplace=True)
print(raw_volunteers.shape)
raw_volunteers.head()
# Out:
# (12401, 10)
#       volunteer_id  gender nationality                    placed  \
# 0  00QD000000gsscc  Female       Irish  Referred to Organisation
# 1  00QD000000gssn1  Female    American  Referred to Organisation
# 2  00QD000000gssoO    Male     British                Not Placed
# 3  00QD000000gssvA    Male       Irish                Not Placed
# 4  00QD000000gssyE  Female     Italian  Referred to Organisation
#
#                volunteer_recruitment_method  \
# 0                           Internet Search
# 1                           Internet Search
# 2                           Internet Search
# 3  Word of Mouth/Referred by another agency
# 4                           Internet Search
#
#                                       skills_profile   county age_group  \
# 0  General Admin/ Office Support; Hospitality/ Be...    Clare     23-35
# 1  Education/ Training; Multi-lingual/ Multi-cult...   Dublin     36-49
# 2  Computer/ Web/ ICT; Drivers; General Admin/ Of...  Kildare     36-49
# 3  Architecture/ Design; Arts/ Music/ Drama; Othe...   Dublin     50-64
# 4  Arts/ Music/ Drama; Education/ Training; Event...   Dublin     36-49
#
#    cause_you_are_interested_in         activity_you_are_interested_in
# 0                      Animals           Short term/seasonal/once off
# 1           Education/Literacy  Teaching/Tutoring/Supporting learning
# 2  Older People/Active Retired    Sports/out door activities/Coaching
# 3        Homelessness/ Housing              Arts (music/drama/crafts)
# 4  Older People/Active Retired                  Befriending/Mentoring

# %% [markdown]
# #### Opportunities All Time

# %%
raw_oppsalltime = pd.read_csv('datadrop_20150325/cleaned_csv/opportunites_all_time.csv'
                             ,parse_dates=[9,10,12,13])
raw_oppsalltime.rename(columns=lambda x: snakeycase(x), inplace=True)
print(raw_oppsalltime.shape)
raw_oppsalltime.head()
# Out:
# (34944, 16)
# /Users/jon/anaconda/envs/datakindvi/lib/python3.4/site-packages/pandas/io/parsers.py:1159: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)
#   volunteer_opportunity_id                             organisation_name  \
# 0          a0020000001ZzT2                                   Way Project
# 1          a002000000BqyH7                           Cobh Youth Services
# 2          a00D000000IPXe8                 Island Key Child Care Service
# 3          a0020000001vmmX  Muscular Dystrophy Ireland - Southern Region
# 4          a00D000000LOb5r                Foroige Westmeath &amp; Offaly
#
#                                             evenings  \
# 0                                                NaN
# 1                 Monday; Tuesday; Wednesday; Friday
# 2                                                NaN
# 3                                                NaN
# 4  Monday; Tuesday; Wednesday; Thursday; Friday; ...
#
#                                            afternoon           morning  \
# 0                                   Monday; Thursday               NaN
# 1                                           Saturday               NaN
# 2                                                NaN  Thursday; Friday
# 3                                                NaN               NaN
# 4  Monday; Tuesday; Wednesday; Thursday; Friday; ...               NaN
#
#        age_restrictions  publish_direct_contact benefits_to_volunteer  \
# 0               over 18                       0                   NaN
# 1                   NaN                       0                   NaN
# 2                   NaN                       0                   NaN
# 3                    18                       0                   NaN
# 4  Over 18 years of age                       1                   NaN
#
#                            skillsqualities_necessary last_activity  \
# 0  understanding of teenagers and issues affectin...    2014-09-30
# 1  Experience of working with youth beneficial bu...    2014-02-28
# 2  Ability to take initiative, ability to work in...    2015-04-03
# 3  We will provide training in First Aid, Manual ...    2014-10-21
# 4                                                NaN    2015-11-02
#
#   last_modified_date  active automatic_deactivation_date publish_date  \
# 0         2013-05-04       0                  2015-11-12          NaT
# 1         2014-08-29       1                  2018-12-31   2013-04-28
# 2         2013-05-29       0                  2018-12-30   2013-04-28
# 3         2014-10-21       0                  2018-12-31   2013-04-28
# 4         2013-05-04       1                  2018-12-30   2013-04-28
#
#   volunteer_opportunity_volunteer_opportunity   skills_required
# 0                      Youth Worker assistant  Youth/ Childcare
# 1                       Youth Cafe Assistants  Youth/ Childcare
# 2                Preschool/Toddler Assistants  Youth/ Childcare
# 3                                Youth Worker  Youth/ Childcare
# 4                              General Leader  Youth/ Childcare

# %% [markdown]
# #### Opportunities Applied For

# %%
raw_oppsappliedfor = pd.read_csv('datadrop_20150325/cleaned_csv/opportunities_applied_for.csv')
raw_oppsappliedfor.rename(columns=lambda x: snakeycase(x), inplace=True)
print(raw_oppsappliedfor.shape)
raw_oppsappliedfor.head()
# Out:
# (31659, 6)
#   volunteer_opportunity_applied_for_name volunteer_volunteer_id  \
# 0                            2014-147236        00QD000000d8ITG
# 1                            2014-163326        00QD000000l12SM
# 2                            2014-147603        00QD000000gsnqI
# 3                            2014-163345        00QD000000gt3vX
# 4                            2014-149145        00QD000000hsnW1
#
#   volunteer_opportunity_applied_for_id volunteer_opportunity_applied_for  \
# 0                      a04D000000T6GC3       Community Mother - Tallaght
# 1                      a04D000000W4oaB            Charity Shop Assistant
# 2                      a04D000000T6JgY       Community Mother - Tallaght
# 3                      a04D000000W4obi            Charity Shop Assistant
# 4                      a04D000000TQaxK       Community Mother - Tallaght
#
#                         organisation_name       current_status_of_application
# 0  Community Mothers Programme - Tallaght         Vacancy no longer available
# 1                  Oxfam Ireland - Galway  Dealing directly with organisation
# 2  Community Mothers Programme - Tallaght         Unsuitable for this vacancy
# 3                  Oxfam Ireland - Galway  Dealing directly with organisation
# 4  Community Mothers Programme - Tallaght       No response from organisation

# %% [markdown]
# #### Placement Info

# %%
raw_placements = pd.read_csv('datadrop_20150325/cleaned_csv/placements.csv')
raw_placements.rename(columns=lambda x: snakeycase(x), inplace=True)
print(raw_placements.shape)
raw_placements.head()
# Out:
# (5897, 8)
#   place_volunteer_connector place_volunteer_id  \
# 0                   v-34825    a01D000000mUsFq
# 1                   v-40103    a01D000000rEFsI
# 2                   v-37087    a01D000000omKeL
# 3                   v-36379    a01D000000oCvKi
# 4                   v-38880    a01D000000rDIHS
#
#   volunteer_opportunity_record_id volunteer_registered_centre  \
# 0                 a00D000000Q6SjS         South Dublin County
# 1                 a00D000000LLY2a                       Kerry
# 2                 a00D000000IMwTv                     Wicklow
# 3                 a00D000000Q5Kod                     Wicklow
# 4                 a00D000000WaLyA                     Wicklow
#
#                               organisation  volunteer_hours  \
# 0                                      NaN                4
# 1                   Kerry General Hospital              104
# 2  Museum of Childhood &amp; Tara's Palace              200
# 3            Bray Community Addiction Team              140
# 4           Luisne Centre for Spirituality                8
#
#   volunteer_opportunity_volunteer_centre  \
# 0                    South Dublin County
# 1                                  Kerry
# 2                                Wicklow
# 3                                Wicklow
# 4                                Wicklow
#
#   volunteer_opportunity_volunteer_opportunity
# 0            Unwrapped Festival Stewards 2013
# 1                   Meet and Greet Volunteers
# 2                           Volunteer Curator
# 3            Drop In Centre Support Volunteer
# 4           Open Day Stewards &amp; Hostesses

# %% [markdown]
# ---

# %% [markdown]
# # Quick Tidy and Merge

# %%
df_vol = raw_volunteers.copy()
df_vol.set_index('volunteer_id', inplace=True)
print(df_vol.shape)
df_vol.head(2)
# Out:
# (12401, 9)
#                  gender nationality                    placed  \
# volunteer_id
# 00QD000000gsscc  Female       Irish  Referred to Organisation
# 00QD000000gssn1  Female    American  Referred to Organisation
#
#                 volunteer_recruitment_method  \
# volunteer_id
# 00QD000000gsscc              Internet Search
# 00QD000000gssn1              Internet Search
#
#                                                     skills_profile  county  \
# volunteer_id
# 00QD000000gsscc  General Admin/ Office Support; Hospitality/ Be...   Clare
# 00QD000000gssn1  Education/ Training; Multi-lingual/ Multi-cult...  Dublin
#
#                 age_group cause_you_are_interested_in  \
# volunteer_id
# 00QD000000gsscc     23-35                     Animals
# 00QD000000gssn1     36-49          Education/Literacy
#
#                         activity_you_are_interested_in
# volunteer_id
# 00QD000000gsscc           Short term/seasonal/once off
# 00QD000000gssn1  Teaching/Tutoring/Supporting learning

# %%
df_oppsapfr = raw_oppsappliedfor.copy()
df_oppsapfr.set_index('volunteer_opportunity_applied_for_id', inplace=True)
print(df_oppsapfr.shape)
df_oppsapfr.head(2)
# Out:
# (31659, 5)
#                                      volunteer_opportunity_applied_for_name  \
# volunteer_opportunity_applied_for_id
# a04D000000T6GC3                                                 2014-147236
# a04D000000W4oaB                                                 2014-163326
#
#                                      volunteer_volunteer_id  \
# volunteer_opportunity_applied_for_id
# a04D000000T6GC3                             00QD000000d8ITG
# a04D000000W4oaB                             00QD000000l12SM
#
#                                      volunteer_opportunity_applied_for  \
# volunteer_opportunity_applied_for_id
# a04D000000T6GC3                            Community Mother - Tallaght
# a04D000000W4oaB                                 Charity Shop Assistant
#
#                                                            organisation_name  \
# volunteer_opportunity_applied_for_id
# a04D000000T6GC3                       Community Mothers Programme - Tallaght
# a04D000000W4oaB                                       Oxfam Ireland - Galway
#
#                                            current_status_of_application
# volunteer_opportunity_applied_for_id
# a04D000000T6GC3                              Vacancy no longer available
# a04D000000W4oaB                       Dealing directly with organisation

# %%
df_oppsaltm = raw_oppsalltime.copy()
df_oppsaltm.set_index('volunteer_opportunity_id', inplace=True)
print(df_oppsaltm.shape)
df_oppsaltm.head(2)
# Out:
# (34944, 15)
#                             organisation_name  \
# volunteer_opportunity_id
# a0020000001ZzT2                   Way Project
# a002000000BqyH7           Cobh Youth Services
#
#                                                     evenings  \
# volunteer_opportunity_id
# a0020000001ZzT2                                          NaN
# a002000000BqyH7           Monday; Tuesday; Wednesday; Friday
#
#                                  afternoon morning age_restrictions  \
# volunteer_opportunity_id
# a0020000001ZzT2           Monday; Thursday     NaN          over 18
# a002000000BqyH7                   Saturday     NaN              NaN
#
#                           publish_direct_contact benefits_to_volunteer  \
# volunteer_opportunity_id
# a0020000001ZzT2                                0                   NaN
# a002000000BqyH7                                0                   NaN
#
#                                                   skillsqualities_necessary  \
# volunteer_opportunity_id
# a0020000001ZzT2           understanding of teenagers and issues affectin...
# a002000000BqyH7           Experience of working with youth beneficial bu...
#
#                          last_activity last_modified_date  active  \
# volunteer_opportunity_id
# a0020000001ZzT2             2014-09-30         2013-05-04       0
# a002000000BqyH7             2014-02-28         2014-08-29       1
#
#                          automatic_deactivation_date publish_date  \
# volunteer_opportunity_id
# a0020000001ZzT2                           2015-11-12          NaT
# a002000000BqyH7                           2018-12-31   2013-04-28
#
#                          volunteer_opportunity_volunteer_opportunity  \
# volunteer_opportunity_id
# a0020000001ZzT2                               Youth Worker assistant
# a002000000BqyH7                                Youth Cafe Assistants
#
#                            skills_required
# volunteer_opportunity_id
# a0020000001ZzT2           Youth/ Childcare
# a002000000BqyH7           Youth/ Childcare

# %%
df_plc = raw_placements.copy()
# df_plc.rename(columns={'volunteer_opportunity_record_id':'volunteer_opportunity_id'}
#               ,inplace=True)
df_plc.set_index('volunteer_opportunity_record_id', inplace=True)
print(df_plc.shape)
df_plc.head(2)
# Out:
# (5897, 7)
#                                 place_volunteer_connector place_volunteer_id  \
# volunteer_opportunity_record_id
# a00D000000Q6SjS                                   v-34825    a01D000000mUsFq
# a00D000000LLY2a                                   v-40103    a01D000000rEFsI
#
#                                 volunteer_registered_centre  \
# volunteer_opportunity_record_id
# a00D000000Q6SjS                         South Dublin County
# a00D000000LLY2a                                       Kerry
#
#                                            organisation  volunteer_hours  \
# volunteer_opportunity_record_id
# a00D000000Q6SjS                                     NaN                4
# a00D000000LLY2a                  Kerry General Hospital              104
#
#                                 volunteer_opportunity_volunteer_centre  \
# volunteer_opportunity_record_id
# a00D000000Q6SjS                                    South Dublin County
# a00D000000LLY2a                                                  Kerry
#
#                                 volunteer_opportunity_volunteer_opportunity
# volunteer_opportunity_record_id
# a00D000000Q6SjS                            Unwrapped Festival Stewards 2013
# a00D000000LLY2a                                   Meet and Greet Volunteers

# %% [markdown]
# ## Merge

# %% [markdown]
# ### Merge volunteers with the opportunities they applied to

# %%
df_volsmadeapps = pd.merge(df_vol, df_oppsapfr, how='outer'
                           , left_index=True, right_on='volunteer_volunteer_id')
df_volsmadeapps = df_volsmadeapps.reset_index().set_index('volunteer_volunteer_id')
print(df_volsmadeapps.shape)
df_volsmadeapps.head(2)
# Out:
# (35234, 14)
#                        volunteer_opportunity_applied_for_id  gender  \
# volunteer_volunteer_id
# 00QD000000gsscc                             a04D000000S6K00  Female
# 00QD000000gssn1                             a04D000000S6KwX  Female
#
#                        nationality                    placed  \
# volunteer_volunteer_id
# 00QD000000gsscc              Irish  Referred to Organisation
# 00QD000000gssn1           American  Referred to Organisation
#
#                        volunteer_recruitment_method  \
# volunteer_volunteer_id
# 00QD000000gsscc                     Internet Search
# 00QD000000gssn1                     Internet Search
#
#                                                            skills_profile  \
# volunteer_volunteer_id
# 00QD000000gsscc         General Admin/ Office Support; Hospitality/ Be...
# 00QD000000gssn1         Education/ Training; Multi-lingual/ Multi-cult...
#
#                         county age_group cause_you_are_interested_in  \
# volunteer_volunteer_id
# 00QD000000gsscc          Clare     23-35                     Animals
# 00QD000000gssn1         Dublin     36-49          Education/Literacy
#
#                                activity_you_are_interested_in  \
# volunteer_volunteer_id
# 00QD000000gsscc                  Short term/seasonal/once off
# 00QD000000gssn1         Teaching/Tutoring/Supporting learning
#
#                        volunteer_opportunity_applied_for_name  \
# volunteer_volunteer_id
# 00QD000000gsscc                                   2014-144138
# 00QD000000gssn1                                   2014-144139
#
#                             volunteer_opportunity_applied_for  \
# volunteer_volunteer_id
# 00QD000000gsscc         2014 Special Olympics Games Volunteer
# 00QD000000gssn1                        Basic Literacy Teacher
#
#                                                         organisation_name  \
# volunteer_volunteer_id
# 00QD000000gsscc                                  Special Olympics Ireland
# 00QD000000gssn1         The Aislinn Education &amp; Support Centre For...
#
#                        current_status_of_application
# volunteer_volunteer_id
# 00QD000000gsscc           No response from volunteer
# 00QD000000gssn1           No response from volunteer

# %% [markdown]
# ### Merge opportunities alltime with those that got placed

# %%
df_oppsalltimeplaced = pd.merge(df_oppsaltm, df_plc, how='left', left_index=True, right_index=True)
df_oppsalltimeplaced.index.name = df_oppsaltm.index.name
print(df_oppsalltimeplaced.shape)
df_oppsalltimeplaced.head(2)
# Out:
# (38363, 22)
#                                      organisation_name evenings afternoon  \
# volunteer_opportunity_id
# a0020000000NAtA           Volunteer Opportunity Holder      NaN       NaN
# a0020000000NAtj           Volunteer Opportunity Holder      NaN       NaN
#
#                          morning age_restrictions  publish_direct_contact  \
# volunteer_opportunity_id
# a0020000000NAtA              NaN              NaN                       0
# a0020000000NAtj              NaN              NaN                       0
#
#                          benefits_to_volunteer skillsqualities_necessary  \
# volunteer_opportunity_id
# a0020000000NAtA                            NaN                       NaN
# a0020000000NAtj                            NaN                       NaN
#
#                          last_activity last_modified_date  \
# volunteer_opportunity_id
# a0020000000NAtA                    NaT         2006-05-25
# a0020000000NAtj                    NaT         2006-05-25
#
#                                               ...                        \
# volunteer_opportunity_id                      ...
# a0020000000NAtA                               ...
# a0020000000NAtj                               ...
#
#                           publish_date  \
# volunteer_opportunity_id
# a0020000000NAtA             2013-07-08
# a0020000000NAtj             2013-07-08
#
#                               volunteer_opportunity_volunteer_opportunity_x  \
# volunteer_opportunity_id
# a0020000000NAtA                                                     Cleaner
# a0020000000NAtj           Face painter, clowns, magicians, alternative e...
#
#                          skills_required place_volunteer_connector  \
# volunteer_opportunity_id
# a0020000000NAtA                      NaN                       NaN
# a0020000000NAtj                      NaN                       NaN
#
#                          place_volunteer_id volunteer_registered_centre  \
# volunteer_opportunity_id
# a0020000000NAtA                         NaN                         NaN
# a0020000000NAtj                         NaN                         NaN
#
#                          organisation volunteer_hours  \
# volunteer_opportunity_id
# a0020000000NAtA                   NaN             NaN
# a0020000000NAtj                   NaN             NaN
#
#                          volunteer_opportunity_volunteer_centre  \
# volunteer_opportunity_id
# a0020000000NAtA                                             NaN
# a0020000000NAtj                                             NaN
#
#                           volunteer_opportunity_volunteer_opportunity_y
# volunteer_opportunity_id
# a0020000000NAtA                                                     NaN
# a0020000000NAtj                                                     NaN
#
# [2 rows x 22 columns]

# %% [markdown]
# # Write to DB

# %%
cnx = sqlite3.connect('datadrop_20150325/cleaned_csv/single_database.db')

# %% [markdown]
# ##### The clean separate tables

# %%
df_vol.to_sql('df_vol', con=cnx, if_exists='replace')
df_oppsaltm.to_sql('df_oppsaltm', con=cnx, if_exists='replace')
df_oppsapfr.to_sql('df_oppsapfr', con=cnx, if_exists='replace')
df_plc.to_sql('df_plc', con=cnx, if_exists='replace')

# %% [markdown]
# ##### The merged tables

# %%
df_volsmadeapps.to_sql('df_volsmadeapps', con=cnx, if_exists='replace')
df_oppsalltimeplaced.to_sql('df_oppsalltimeplaced', con=cnx, if_exists='replace')

# %% [markdown]
# ---
#
# DataKind Dublin 2005
