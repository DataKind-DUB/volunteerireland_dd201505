# %% [markdown]
# # Initial analysis
#
# Trying to answer question 1

# %% [markdown]
# # Setup

# %%
## Interactive magics - comment out if running from another script
# %matplotlib inline
# %qtconsole --colors=linux --ConsoleWidget.font_size=12 --ConsoleWidget.font_family='Consolas'

# %%
import sqlite3
import numpy as np
import pandas as pd
import seaborn as sns

pd.set_option('display.mpl_style', 'default')
pd.set_option('display.notebook_repr_html', True)
np.random.seed(0)

# %%
cnx = sqlite3.connect('data/volunteerireland_datadive2015.db')

# %% [markdown]
# ## Load Data

# %%
dfv = pd.read_sql('select * from vi_merged', cnx, index_col='index')
print(dfv.shape)
dfv.head()
# Out:
# (780548, 15)
#        altm_id altm_organisation_id altm_volunteer_opportunity_id  orgs_id  \
# index
# 0            0      001D000001hzVeF               a00D000000a2hWM      NaN
# 1            1      001D000001hzHbI               a00D000000a2fnU      NaN
# 2            2      001D000001hz3rh               a00D000000a2ejO      NaN
# 3            3      001D000001hz1WN               a00D000000a2edf      NaN
# 4            4      001D000001hz175               a00D000000a2ecw      NaN
#
#       orgs_organisation_id  apfr_id apfr_vop_name apfr_volunteer_volunteer_id  \
# index
# 0                     None      NaN          None                        None
# 1                     None      NaN          None                        None
# 2                     None      NaN          None                        None
# 3                     None      NaN          None                        None
# 4                     None      NaN          None                        None
#
#        vol_id_apfr vol_volunteer_id_apfr  plc_id  \
# index
# 0              NaN                  None     NaN
# 1              NaN                  None     NaN
# 2              NaN                  None     NaN
# 3              NaN                  None     NaN
# 4              NaN                  None     NaN
#
#       plc_volunteer_opportunity_record_id plc_volunteer_id  vol_id_plc  \
# index
# 0                                    None             None         NaN
# 1                                    None             None         NaN
# 2                                    None             None         NaN
# 3                                    None             None         NaN
# 4                                    None             None         NaN
#
#       vol_volunteer_id_plc
# index
# 0                     None
# 1                     None
# 2                     None
# 3                     None
# 4                     None

# %%
dfoppsaltm = pd.read_sql('select * from dfoppsaltm', cnx, index_col='index')
print(dfoppsaltm.shape)
dfoppsaltm.head()
# Out:
# (35494, 29)
#          altm_created_date altm_volunteer_opportunity_id altm_organisation_id  \
# index
# 0      2015-05-14 00:00:00               a00D000000a2hWM      001D000001hzVeF
# 1      2015-05-13 00:00:00               a00D000000a2fnU      001D000001hzHbI
# 2      2015-05-12 00:00:00               a00D000000a2ejO      001D000001hz3rh
# 3      2015-05-12 00:00:00               a00D000000a2edf      001D000001hz1WN
# 4      2015-05-12 00:00:00               a00D000000a2ecw      001D000001hz175
#
#                       altm_organisation_name  \
# index
# 0                           Involve Salthill
# 1                               Bloom Fringe
# 2                        Make-A-Wish Ireland
# 3         Knockatallon Community Development
# 4      Multiple Sclerosis Society of Ireland
#
#       altm_volunteer_opportunity_volunteer_opportunity  \
# index
# 0                                   Cycle group leader
# 1                       Festival Steward - City Centre
# 2                           County Volunteer Wish Team
# 3               Road Marshalling for Fundraising Event
# 4      a companion to a person with multiple sclerosis
#
#       altm_activity_that_reflects_opportunity   altm_volunteer_bureau  \
# index
# 0         Sports/out door activities/Coaching                  Galway
# 1                       Events and stewarding             Dublin City
# 2                     Support and Key working  Dun Laoghaire/Rathdown
# 3                       Events and stewarding                Monaghan
# 4                       Befriending/Mentoring             Dublin City
#
#       altm_county                                       altm_morning  \
# index
# 0          Galway                                               None
# 1          Dublin                                           Saturday
# 2          Dublin  Monday; Tuesday; Wednesday; Thursday; Friday; ...
# 3        Monaghan                                               None
# 4          Dublin                                               None
#
#                                           altm_afternoon   ...     \
# index                                                      ...
# 0                                                   None   ...
# 1                                               Saturday   ...
# 2      Monday; Tuesday; Wednesday; Thursday; Friday; ...   ...
# 3                                                   None   ...
# 4      Monday; Tuesday; Wednesday; Thursday; Friday; ...   ...
#
#       altm_publish_direct_contact altm_active  \
# index
# 0                               0           0
# 1                               1           1
# 2                               0           0
# 3                               0           0
# 4                               0           0
#
#       altm_number_of_volunteers_required altm_automatic_de-activation_date  \
# index
# 0                                      2               2015-06-30 00:00:00
# 1                                     20               2015-05-31 00:00:00
# 2                                      5               2016-07-16 00:00:00
# 3                                     10               2015-08-12 00:00:00
# 4                                      1               2015-08-12 00:00:00
#
#          altm_publish_date                               altm_skills_required  \
# index
# 0                     None                            Fitness/ Health/ Beauty
# 1      2015-05-14 00:00:00   Event management/ Fundraising; Personable Skills
# 2                     None  Hospitality/ Befriending; Personable Skills; Y...
# 3                     None                                               None
# 4                     None                                  Personable Skills
#
#                          altm_skills/qualities_necessary  \
# index
# 0      Good communication skills; motivational skills...
# 1      No specific skills but a willingness to engage...
# 2      Skills required are friendly manner, listening...
# 3                                                   None
# 4      someone who likes dogs! and could befriend the...
#
#       altm_suitable_for_corporates/groups  \
# index
# 0                                     Yes
# 1                                     Yes
# 2                                     Yes
# 3                                     Yes
# 4                                      No
#
#                               altm_benefits_to_volunteer  altm_id
# index
# 0      The volunteer will gain experience in both co-...        0
# 1                                                   None        1
# 2                                                   None        2
# 3                                                   None        3
# 4      contact from a person living with multiple scl...        4
#
# [5 rows x 29 columns]

# %%
dforgs = pd.read_sql('select * from dforgs', cnx, index_col='index')
print(dforgs.shape)
dforgs.head()
# Out:
# (7764, 16)
#          orgs_created_date orgs_organisation_id  \
# index
# 0      2012-12-18 00:00:00      001D000000zg6AQ
# 1      2012-08-14 00:00:00      001D000000tvhyQ
# 2      2007-01-23 00:00:00      00120000004o3iu
# 3      2012-10-02 00:00:00      001D000000w8uw9
# 4      2008-05-14 00:00:00      0012000000A4dWS
#
#                        orgs_organisation_name orgs_county  \
# index
# 0                               Cork Job Club        Cork
# 1      Knocknaheeny/Hollyhill Justice Project        Cork
# 2                Lough Parish Meals On Wheels        Cork
# 3                 Focus Ireland - Cork branch        Cork
# 4                     Cork Sports Partnership        Cork
#
#       orgs_local_area__dublin  \
# index
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
#
#                                orgs_aims_of_organisation  \
# index
# 0      Cork Job Club aims to expand awareness and hel...
# 1      The project's main focus is as a Garda Youth D...
# 2      To provide meals on wheels mainly to the elder...
# 3      Focus Ireland works to prevent people becoming...
# 4      The mission of Cork Sports Partnership is to i...
#
#       orgs_volunteer_bureau orgs_organisation_status  \
# index
# 0                      Cork                   Active
# 1                      Cork                   Active
# 2                      Cork                   Active
# 3                      Cork                   Active
# 4                      Cork                   Active
#
#         orgs_cause_of_organisation orgs_how_did_you_hear_about_our_service  \
# index
# 0                     Unemployment                           Word of Mouth
# 1                 Social Inclusion                           Word of Mouth
# 2      Older People/Active Retired                           Word of Mouth
# 3            Homelessness/ Housing                           Word of Mouth
# 4        Sports/Outdoor activities                           Word of Mouth
#
#       orgs_which_best_describes_your_organisation  \
# index
# 0                              Registered Charity
# 1                              Registered Charity
# 2                              Registered Charity
# 3                              Registered Charity
# 4               Non Profit without Charity Number
#
#       orgs_do_you_have_a_volunteer_policy  \
# index
# 0                                      No
# 1                                     Yes
# 2                                      No
# 3                                     Yes
# 4                                     Yes
#
#       orgs_how_many_volunteers_do_you_involve  \
# index
# 0                          less than 5 people
# 1                          less than 5 people
# 2                                 5-10 people
# 3      We currently do not involve volunteers
# 4      We currently do not involve volunteers
#
#       orgs_how_many_employees_are_in_your_org  \
# index
# 0                          less than 5 people
# 1                          less than 5 people
# 2                          less than 5 people
# 3                                 5-10 people
# 4                                 5-10 people
#
#                        orgs_how_do_you_manage_volunteers  orgs_id
# index
# 0      We have a paid member of staff who is a part-t...        0
# 1      We have a paid member of staff who is a full-t...        1
# 2      We have a volunteer who is responsible for Vol...        2
# 3      We have a paid member of staff who is a full-t...        3
# 4      Volunteer Management is shared between staff a...        4

# %%
dfoppsapfr = pd.read_sql('select * from dfoppsapfr', cnx, index_col='index'
                        ,parse_dates=['apfr_volunteer_opportunity_applied_for_created_date'])
print(dfoppsapfr.shape)
dfoppsapfr.head()
# Out:
# (110612, 10)
#       apfr_volunteer_opportunity_applied_for_volunteer_opportunity_applied_for__name  \
# index
# 0                                            2015-188435
# 1                                            2015-188434
# 2                                            2015-188433
# 3                                            2015-188432
# 4                                            2015-188431
#
#        apfr_volunteers_required  \
# index
# 0                             1
# 1                             1
# 2                             4
# 3                             5
# 4                             1
#
#       apfr_volunteer_opportunity_applied_for_created_date  \
# index
# 0                                             2015-05-05
# 1                                             2015-05-05
# 2                                             2015-05-05
# 3                                             2015-05-05
# 4                                             2015-05-05
#
#       apfr_volunteer_volunteer_id apfr_volunteer_opportunity_applied_for_id  \
# index
# 0                 00QD000000r6Ni2                           a04D000000aYWaQ
# 1                 00QD000000prM1r                           a04D000000aYWaL
# 2                 00QD000000QofvS                           a04D000000aYWaG
# 3                 00QD000000r5HY5                           a04D000000aYWaB
# 4                 00QD000000r6NO0                           a04D000000aYWa6
#
#          apfr_vop_name apfr_volunteer_opportunity_applied_for  \
# index
# 0      a00D000000LNaRk                   Family Law Mediators
# 1      a00D000000a2Gym       Community Engagement Team Member
# 2      a00D000000a2KoB          Darkness Into Light Walk 2015
# 3      a00D000000WZTvk             Information Liason Officer
# 4      a00D000000LLe1w           Douglas Tidy Towns Volunteer
#
#                   apfr_organisation_name  \
# index
# 0        The Guardian Children's Project
# 1                               BlueFire
# 2      Pieta House - Darkness into Light
# 3                         EnGage Kildare
# 4                     Douglas Tidy Towns
#
#            apfr_current_status_of_application  apfr_id
# index
# 0             Registered interest in this Opp        0
# 1             Registered interest in this Opp        1
# 2           Passed on details to organisation        2
# 3             Registered interest in this Opp        3
# 4      Details of contact passed to volunteer        4

# %%
dfplc = pd.read_sql('select * from dfplc', cnx, index_col='index'
                   ,parse_dates=['plc_place_volunteer_created_date'
                                ,'plc_volunteer_opportunity_created_date'])
print(dfplc.shape)
dfplc.head()
# Out:
# (39821, 12)
#       plc_place_volunteer_connector plc_volunteer_id plc_place_volunteer_id  \
# index
# 0                           v-10825  00Q2000000E7TXM        a012000000QQACg
# 1                           v-33133  00QD000000ekhy5        a01D000000lWTIj
# 2                           v-40009  00QD000000XHKN2        a01D000000rEETh
# 3                           v-11012  00Q2000000E83Nm        a012000000QQTTv
# 4                           v-11994  00Q2000000BAHaT        a012000000Sapby
#
#       plc_place_volunteer_created_date plc_volunteer_opportunity_created_date  \
# index
# 0                           2009-11-30                             2007-10-30
# 1                           2013-10-14                             2011-09-15
# 2                           2014-11-18                             2013-08-06
# 3                           2009-12-10                             2009-05-08
# 4                           2010-03-09                             2009-01-14
#
#       plc_volunteer_opportunity_record_id plc_volunteer_registered_centre  \
# index
# 0                         a0020000004lHjP                         Kildare
# 1                         a00D000000IOigU                          Offaly
# 2                         a00D000000Q5juz          Dun Laoghaire/Rathdown
# 3                         a002000000AkGnM          Dun Laoghaire/Rathdown
# 4                         a0020000009dQuO                           Sligo
#
#                                         plc_organisation  plc_volunteer_hours  \
# index
# 0                                         The Bridge CDP                  104
# 1                 Birr Mentality Handicapped Association                   12
# 2      Society of St. Vincent de Paul - SVP Dublin Re...                  104
# 3                                     Making Connections                   20
# 4                                     Irish Therapy Dogs                   52
#
#       plc_volunteer_opportunity_volunteer_centre  \
# index
# 0                                        Kildare
# 1                                           None
# 2                                    Dublin City
# 3                                           None
# 4                                          Sligo
#
#          plc_volunteer_opportunity_volunteer_opportunity  plc_id
# index
# 0                               Homework Club Mentor CDP       0
# 1                                         Support Worker       1
# 2      Volunteer for Society of Saint Vincent de Paul...       2
# 3                                             Web Design       3
# 4                                            Pet Visitor       4

# %%
dfvol = pd.read_sql('select * from dfvol', cnx, index_col='index')
print(dfvol.shape)
dfvol.head()
# Out:
# (103035, 22)
#       vol_volunteer_id      vol_create_date  \
# index
# 0      00Q2000000E7wXL  2009-11-09 00:00:00
# 1      00Q2000000Hl336  2010-05-19 00:00:00
# 2      00QD000000NXhm2  2011-05-17 00:00:00
# 3      00QD000000QoUOG  2011-11-17 00:00:00
# 4      00QD000000Uye1D  2012-07-04 00:00:00
#
#       vol_how_long_do_you_wish_to_volunteer_for vol_age_group  \
# index
# 0                                          None         36-49
# 1                                          None         16-25
# 2                                          None         50-59
# 3                                          None         26-35
# 4                                          None         26-35
#
#       vol_why_do_you_want_to_volunteer_now vol_volunteer_status  \
# index
# 0                  Recently made redundant           Registered
# 1                                Free time  Registered Interest
# 2                          Work Experience           Registered
# 3                      Because I was asked           Registered
# 4                                Free time           Registered
#
#       vol_method_of_contact_with_volunteer vol_face_to_face vol_gender  \
# index
# 0                                     None             None       Male
# 1                Contact by phone/internet      Appointment       Male
# 2                Contact by phone/internet             None     Female
# 3                                     None             None       Male
# 4                Contact by phone/internet             None     Female
#
#       vol_nationality  ...   vol_volunteered_before vol_volunteer_bureau  \
# index                  ...
# 0               Irish  ...                       No               Galway
# 1          Zimbabwean  ...                       No                 Cork
# 2            Nigerian  ...                       No  South Dublin County
# 3               Irish  ...                      Yes               Galway
# 4               Irish  ...                       No  South Dublin County
#
#       vol_local_area__dublin          vol_volunteer_recruitment_method  \
# index
# 0                       None                           Internet Search
# 1                       None                           Internet Search
# 2                       None                           Internet Search
# 3                       None  Word of Mouth/Referred by another agency
# 4                       None  Word of Mouth/Referred by another agency
#
#       vol_activity_you_are_interested_in vol_cause_you_are_interested_in  \
# index
# 0                                   None                            None
# 1                                   None                            None
# 2             Administrative/Office work                          Carers
# 3                                   None                            None
# 4                                   None                            None
#
#                                     vol_skills_qualities vol_skills_profile  \
# index
# 0      Worked in computer support for over 11 years, ...               None
# 1      Ecdl -Coumputer course  retail experience kitc...               None
# 2      Practical Care Skills\nManual Handling Skills\...               None
# 3                                               Various.               None
# 4      I have worked in administration in the offices...               None
#
#       vol_county vol_id
# index
# 0           None      0
# 1           None      1
# 2         Dublin      2
# 3           None      3
# 4           None      4
#
# [5 rows x 22 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### Count unique vols who applied

# %%
print(dfv.groupby('vol_id_apfr').size().shape[0])
ax = dfv.groupby('vol_id_apfr').size().plot(kind='box'
                ,showfliers=False, showmeans=True, vert=False)
# Out:
# 39769

# %% [markdown]
# ### Count unique vols who applied by year

# %%
dfv_app = pd.merge(dfv, dfoppsapfr
                   ,how='left', left_on='apfr_id', right_on='apfr_id')

# %%
dfv_app['app_year'] = dfv_app['apfr_volunteer_opportunity_applied_for_created_date'].apply(
            lambda x: x.year)
dfv_app.groupby(['vol_id_apfr','app_year']).size().unstack().count()
# Out:
# app_year
# 2010      121
# 2011      465
# 2012    13009
# 2013    13921
# 2014    13133
# 2015     5732
# dtype: int64

# %%
ax = dfv_app.groupby(['vol_id_apfr','app_year']).size().unstack().plot(
            kind='box', showfliers=False, showmeans=True, figsize=(12, 6))
ax.set_title('Distribution of count of applications per volunteer per year')

# %% [markdown]
# ---

# %% [markdown]
# ### Count unique vols who placed

# %%
print(dfv.groupby('vol_id_plc').size().shape[0])
ax = dfv.groupby('vol_id_plc').size().plot(kind='box'
                ,showfliers=False, showmeans=True, vert=False)
# Out:
# 19400

# %% [markdown]
# ### Count unique vols who placed by year

# %%
dfv_plc = pd.merge(dfv, dfplc
                   ,how='left', left_on='plc_id', right_on='plc_id')

# %%
dfv_plc['app_year'] = dfv_plc['plc_place_volunteer_created_date'].apply(
            lambda x: x.year)
dfv_plc.groupby(['vol_id_plc','app_year']).size().unstack().count()
# Out:
# app_year
# 2006     195
# 2007     322
# 2008     746
# 2009    1292
# 2010    1631
# 2011    2265
# 2012    4468
# 2013    4573
# 2014    4404
# 2015    1604
# dtype: int64

# %%
ax = dfv_plc.groupby(['vol_id_plc','app_year']).size().unstack().plot(
            kind='box', showfliers=False, showmeans=True, figsize=(12, 6))
ax.set_title('Distribution of count of placements per volunteer per year')
